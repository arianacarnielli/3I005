# %% [markdown]
# # Projet 3 : Analyse de séquences génomiques

# %% [markdown]
# Ariana Carnielli & Yasmine Ikhelif

# %%
import Projet_Bioinfo as pb
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import factorial
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

import projet
nucleotide_inverse = {0:'A',1:'C',2:'G',3:'T'}

# %% [markdown]
# ## Préliminaires : données et lecture des fichiers

# %% [markdown]
# #### Question 1

# %%
for filename in ["sequences/regulatory_seq_PHO.fasta",
                 "sequences/regulatory_seqs_GAL.fasta",
                 "sequences/regulatory_seqs_MET.fasta",
                 "sequences/yeast_s_cerevisae_genomic_chr1-4.fna"]:
    dico_chro = pb.read_fasta(filename)
    total = 0
    for chrome in dico_chro:
        total += sum(pb.nucleotide_count(dico_chro[chrome]))
    print("Fichier {} : {} séquences, {} nucléotides.".format(filename, len(dico_chro.keys()), total))
# Out:
# Fichier sequences/regulatory_seq_PHO.fasta : 5 séquences, 4000 nucléotides.
# Fichier sequences/regulatory_seqs_GAL.fasta : 7 séquences, 5608 nucléotides.
# Fichier sequences/regulatory_seqs_MET.fasta : 9 séquences, 7200 nucléotides.
# Fichier sequences/yeast_s_cerevisae_genomic_chr1-4.fna : 4 séquences, 2515853 nucléotides.

# %% [markdown]
# #### Question 2

# %%
dico_chro = pb.read_fasta("sequences/yeast_s_cerevisae_genomic_chr1-4.fna")
liste_gen = []
for chrome in dico_chro:
    liste_gen += dico_chro[chrome] 

a, c, g, t = pb.nucleotide_frequency(liste_gen)
print("Fréquence des nucléotides :")
print("A : {:.5f}".format(a))
print("C : {:.5f}".format(c))
print("G : {:.5f}".format(g))
print("T : {:.5f}".format(t))
# Out:
# Fréquence des nucléotides :
# A : 0.29984
# C : 0.20110
# G : 0.20000
# T : 0.29907

# %% [markdown]
# #### Question 3
#
# Test de la fonction `logproba`.

# %%
p_log = projet.logproba(liste_gen, (a,c,g,t))
print("Log-probabilité de la séquence dans liste_gen :", p_log)
p_log = projet.logproba([pb.nucleotide[i] for i in "CGT"], (a,c,g,t))
print("Log_probabilité de la séquence CGT :", p_log)
# Out:
# Log-probabilité de la séquence dans liste_gen : -3438164.462646954
# Log_probabilité de la séquence CGT : -4.420488639322931

# %% [markdown]
# #### Question 4
#
# Test de la fonction `logprobafast`.

# %%
p_log_fast = projet.logprobafast(pb.nucleotide_count(liste_gen), (a,c,g,t))
print("Log-probabilité de la séquence dans liste_gen :", p_log_fast)
p_log_fast = projet.logprobafast([0, 1, 1, 1], (a,c,g,t))
print("Log_probabilité de la séquence CGT :", p_log_fast)
# Out:
# Log-probabilité de la séquence dans liste_gen : -3438164.4626395022
# Log_probabilité de la séquence CGT : -4.420488639322931

# %% [markdown]
# ## Annotation des régions promoteurs

# %% [markdown]
# ### Description Empirique, préliminaires

# %% [markdown]
# Création des listes de nucléotides à partir des trois fichiers.

# %%
dico_PHO = pb.read_fasta("sequences/regulatory_seq_PHO.fasta")
dico_GAL = pb.read_fasta("sequences/regulatory_seqs_GAL.fasta")
dico_MET = pb.read_fasta("sequences/regulatory_seqs_MET.fasta")

liste_PHO = []
liste_GAL = []
liste_MET = []

for code in dico_PHO:
    liste_PHO += dico_PHO[code]
    
for code in dico_GAL:
    liste_GAL += dico_GAL[code]
    
for code in dico_MET:
    liste_MET += dico_MET[code]

# %% [markdown]
# #### Question 1(a)
# Test de la fonction `code`.

# %%
test = [3, 0, 1]
projet.code(test, len(test))
# Out:
# 49

# %% [markdown]
# #### Question 1(b)
# Test de la fonction `inverse`.

# %%
projet.inverse(49, 3)
# Out:
# [3, 0, 1]

# %% [markdown]
# #### Question 1(c)
#
# Test de la fonction `comptage`.

# %%
seq = "ATCATG"
print("Représentation par chaine de caractères :", projet.comptage(seq, 2))
seq = pb.encode_sequence(seq)
print("Représentation par liste d'entiers :", projet.comptage(seq, 2))
# Out:
# Représentation par chaine de caractères : {'AT': 2, 'TC': 1, 'CA': 1, 'TG': 1}
# Représentation par liste d'entiers : {3: 2, 13: 1, 4: 1, 14: 1}

# %% [markdown]
# #### Question 2

# %%
print("Espérance du nombre d'occurences de chaque mot de taille 2 dans une séquence de taille 100 :")
for i, esp in enumerate(projet.comptage_attendu([a, c, g, t], 2, 100)):
    print("Mot {} : {:.4f}".format(projet.inverse(i, 2), esp))
# Out:
# Espérance du nombre d'occurences de chaque mot de taille 2 dans une séquence de taille 100 :
# Mot [0, 0] : 8.9002
# Mot [0, 1] : 5.9695
# Mot [0, 2] : 5.9367
# Mot [0, 3] : 8.8774
# Mot [1, 0] : 5.9695
# Mot [1, 1] : 4.0038
# Mot [1, 2] : 3.9818
# Mot [1, 3] : 5.9541
# Mot [2, 0] : 5.9367
# Mot [2, 1] : 3.9818
# Mot [2, 2] : 3.9599
# Mot [2, 3] : 5.9214
# Mot [3, 0] : 8.8774
# Mot [3, 1] : 5.9541
# Mot [3, 2] : 5.9214
# Mot [3, 3] : 8.8546

# %% [markdown]
# #### Question 3

# %%
projet.graphe_occurrences((a, c, g, t), 2, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                          "graphe_occurrences_2.png")

# %%
projet.graphe_occurrences((a, c, g, t), 4, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                          "graphe_occurrences_4.png")

# %%
projet.graphe_occurrences((a, c, g, t), 6, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                          "graphe_occurrences_6.png")

# %%
projet.graphe_occurrences((a, c, g, t), 8, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                          "graphe_occurrences_8.png")

# %% [markdown]
# ### Simulation de séquences aléatoires

# %% [markdown]
# #### Question 1

# %% [markdown]
# Test de la fonction `simule_sequence`.

# %%
test = projet.simule_sequence(1000000, (a, c, g, t))

# %% [markdown]
# #### Question 2
# On fait le graphe avec les occurrences pour une séquence de longueur 1000000 et des mots de taille 6.

# %%
projet.graphe_occurrences((a, c, g, t), 6, {"Séquence simulée" : test}, "graphe_occurrences_simul.png")

# %% [markdown]
# #### Question 3
# Test de la fonction `proba_empirique`.

# %%
probas = {}
for mot in ["ATCTGC", "ATATAT", "TTTAAA", "AAAAAA"]:
    print("Mot "+mot+":")
    probas[mot] = projet.proba_empirique(pb.encode_sequence(mot), 10000, (a, c, g, t), 1000)
    print(probas[mot])
    print("")
# Out:
# Mot ATCTGC:
# {3: 0.211, 5: 0.048, 4: 0.109, 1: 0.235, 0: 0.117, 2: 0.261, 6: 0.014, 7: 0.005}
#
# Mot ATATAT:
# {4: 0.085, 9: 0.114, 11: 0.044, 5: 0.119, 7: 0.116, 8: 0.124, 3: 0.064, 10: 0.088, 6: 0.132, 12: 0.03, 2: 0.025, 18: 0.001, 15: 0.008, 14: 0.016, 16: 0.005, 13: 0.023, 0: 0.001, 1: 0.005}
#
# Mot TTTAAA:
# {7: 0.145, 9: 0.108, 10: 0.084, 8: 0.131, 4: 0.079, 6: 0.148, 5: 0.104, 12: 0.039, 3: 0.067, 11: 0.04, 1: 0.003, 13: 0.02, 2: 0.016, 14: 0.008, 16: 0.001, 15: 0.005, 0: 0.002}
#
# Mot AAAAAA:
# {3: 0.076, 9: 0.063, 2: 0.043, 8: 0.085, 1: 0.019, 5: 0.113, 10: 0.062, 14: 0.025, 7: 0.108, 4: 0.094, 6: 0.137, 15: 0.013, 18: 0.004, 19: 0.001, 11: 0.056, 12: 0.046, 13: 0.029, 21: 0.001, 16: 0.009, 0: 0.007, 23: 0.001, 17: 0.004, 27: 0.001, 20: 0.002, 24: 0.001}

# %% [markdown]
# #### Question 4

# %%
for mot in probas:
    fig, ax = plt.subplots(figsize=(7, 7))
    ax.bar(probas[mot].keys(), probas[mot].values())
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.set_title("Histogramme des occurrences de "+mot)
    ax.set_xlabel("Occurrences")
    ax.set_ylabel("Probabilité estimée")
    fig.savefig("Rapport/Figures/histogramme_"+mot+".png")

# %% [markdown]
# #### Question 5
#
# On représente graphiquement les intervalles de confiance avec des lignes sur les barres.

# %%
N = 1000 # Valeur utilisée dans le calcul de la probabilité empirique.
for mot in probas:
    fig, ax = plt.subplots(figsize=(7, 7))
    keys = np.array([x for x in probas[mot].keys()])
    vals = np.array([x for x in probas[mot].values()])
    ax.bar(keys, vals, yerr=1.96*np.sqrt(vals*(1-vals)/N), ecolor="C1", capsize=5)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.set_title("Histogramme des occurrences de "+mot)
    ax.set_xlabel("Occurrences")
    ax.set_ylabel("Probabilité estimée")
    fig.savefig("Rapport/Figures/histogramme_"+mot+"_errorbar.png")

# %% [markdown]
# ### Modèles de dinucléotides et trinucléotides

# %% [markdown]
# #### Question 2
# Test de la fonction `estim_M`.

# %%
M = projet.estim_M(liste_gen)
print("Matrice M estimée :")
print(M)
# Out:
# Matrice M estimée :
# [[0.3250462  0.18551797 0.20059204 0.28884379]
#  [0.33570778 0.2092548  0.1575632  0.29747422]
#  [0.31321125 0.20244971 0.20774423 0.27659481]
#  [0.24149361 0.2103415  0.2227537  0.32541118]]

# %% [markdown]
# #### Question 3
# Test de la fonction `simule_Markov`.

# %%
print(projet.simule_Markov((a, c, g, t), M, 50))
# Out:
# [3 0 3 3 1 0 0 2 1 0 1 0 1 0 0 0 3 0 3 1 0 3 2 2 2 3 0 3 3 2 1 3 3 3 3 2 2
#  2 3 0 2 0 3 3 1 1 0 2 0 3]

# %% [markdown]
# #### Question 4
# Test de la fonction `logproba_mot_Markov`.

# %%
projet.logproba_mot_Markov([1, 2, 3], (a, c, g, t), M)
# Out:
# -4.737073390417531

# %% [markdown]
# #### Question 5
# Test de la fonction `comptage_attendu_Markov`.

# %%
print("Espérance du nombre d'occurences de chaque mot de taille 2 dans une séquence de taille 100 :")
for i, esp in enumerate(projet.comptage_attendu_Markov([a, c, g, t], M, 2, 100)):
    print("Mot {} : {:.4f}".format(projet.inverse(i, 2), esp))
# Out:
# Espérance du nombre d'occurences de chaque mot de taille 2 dans une séquence de taille 100 :
# Mot [0, 0] : 9.6486
# Mot [0, 1] : 5.5069
# Mot [0, 2] : 5.9543
# Mot [0, 3] : 8.5740
# Mot [1, 0] : 6.6836
# Mot [1, 1] : 4.1661
# Mot [1, 2] : 3.1369
# Mot [1, 3] : 5.9224
# Mot [2, 0] : 6.2015
# Mot [2, 1] : 4.0084
# Mot [2, 2] : 4.1133
# Mot [2, 3] : 5.4765
# Mot [3, 0] : 7.1500
# Mot [3, 1] : 6.2277
# Mot [3, 2] : 6.5952
# Mot [3, 3] : 9.6346

# %% [markdown]
# #### Question 6

# %%
print("Comparaison de l'espérance du nombre d'occurences de chaque mot de taille 2 dans une séquence de taille 100 "+
      "pour le modèle indépendant (nucléotide) et le modèle par chaîne de Markov (dinucléotide) :")
cptNucl = projet.comptage_attendu([a, c, g, t], 2, 100)
cptDinucl = projet.comptage_attendu_Markov([a, c, g, t], M, 2, 100)
print("Mot Nucléotide Dinucléotide")
for i in range(len(cptNucl)):
    print("".join([nucleotide_inverse[j] for j in projet.inverse(i, 2)]), end="  ")
    print("{:.4f}".format(cptNucl[i]), end="     ")
    print("{:.4f}".format(cptDinucl[i]))
# Out:
# Comparaison de l'espérance du nombre d'occurences de chaque mot de taille 2 dans une séquence de taille 100 pour le modèle indépendant (nucléotide) et le modèle par chaîne de Markov (dinucléotide) :
# Mot Nucléotide Dinucléotide
# AA  8.9002     9.6486
# AC  5.9695     5.5069
# AG  5.9367     5.9543
# AT  8.8774     8.5740
# CA  5.9695     6.6836
# CC  4.0038     4.1661
# CG  3.9818     3.1369
# CT  5.9541     5.9224
# GA  5.9367     6.2015
# GC  3.9818     4.0084
# GG  3.9599     4.1133
# GT  5.9214     5.4765
# TA  8.8774     7.1500
# TC  5.9541     6.2277
# TG  5.9214     6.5952
# TT  8.8546     9.6346

# %% [markdown]
# #### Question 7

# %%
projet.graphe_occurrences_Markov((a, c, g, t), M, 2, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                                 "graphe_occurrences_Markov_2.png")

# %%
projet.graphe_occurrences_Markov((a, c, g, t), M, 4, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                                 "graphe_occurrences_Markov_4.png")

# %%
projet.graphe_occurrences_Markov((a, c, g, t), M, 6, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                                 "graphe_occurrences_Markov_6.png")

# %%
projet.graphe_occurrences_Markov((a, c, g, t), M, 8, {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET},
                                 "graphe_occurrences_Markov_8.png")

# %% [markdown]
# ### Probabilités de mots

# %% [markdown]
# #### Question 3
# On calcule d'abord les probabilités empiriques du nombre d'occurrences des mots ATCTGC, ATATAT, TTTAAA et AAAAAA avec le modèle dinucléotide.

# %%
probas = {}
L = 10000
for mot in ["ATCTGC", "ATATAT", "TTTAAA", "AAAAAA"]:
    print("Mot "+mot+":")
    probas[mot] = projet.proba_empirique_Markov(pb.encode_sequence(mot), L, (a, c, g, t), M, 1000)
    print(probas[mot])
    print("")
# Out:
# Mot ATCTGC:
# {3: 0.216, 1: 0.195, 0: 0.089, 2: 0.266, 4: 0.141, 5: 0.059, 8: 0.004, 7: 0.007, 6: 0.022, 9: 0.001}
#
# Mot ATATAT:
# {3: 0.164, 5: 0.17, 4: 0.189, 7: 0.08, 2: 0.122, 1: 0.069, 6: 0.109, 0: 0.027, 9: 0.015, 8: 0.034, 10: 0.014, 12: 0.003, 13: 0.002, 11: 0.002}
#
# Mot TTTAAA:
# {9: 0.136, 6: 0.12, 15: 0.011, 11: 0.068, 12: 0.049, 5: 0.083, 7: 0.133, 8: 0.148, 3: 0.026, 2: 0.011, 10: 0.098, 13: 0.035, 4: 0.057, 14: 0.016, 16: 0.002, 17: 0.002, 1: 0.004, 18: 0.001}
#
# Mot AAAAAA:
# {5: 0.045, 21: 0.013, 12: 0.091, 14: 0.059, 16: 0.043, 9: 0.069, 13: 0.076, 6: 0.066, 8: 0.083, 15: 0.05, 23: 0.003, 10: 0.077, 24: 0.004, 2: 0.02, 11: 0.074, 7: 0.085, 19: 0.011, 3: 0.018, 25: 0.004, 22: 0.008, 4: 0.032, 18: 0.023, 17: 0.027, 1: 0.007, 20: 0.008, 26: 0.001, 29: 0.001, 30: 0.001, 27: 0.001}

# %%
for mot in probas:
    fig, ax = plt.subplots(figsize=(7, 7))
    # Probabilité calculée avec une loi de Poisson :
    p = np.exp(projet.logproba_mot_Markov(pb.encode_sequence(mot), (a, c, g, t), M)) # Probabilité du mot
    lamb = p * (L - len(mot) + 1) # Paramètre de la loi de Poisson

    nMax = max(probas[mot].keys())+1
    k = np.arange(nMax)
    
    ax.bar(probas[mot].keys(), probas[mot].values(), zorder=1, label="Probabilité empirique")
    ax.scatter(k, (lamb**k)/factorial(k) * np.exp(-lamb), zorder=2, label="Loi de Poisson")
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.set_title("Histogramme des occurrences de "+mot)
    ax.set_xlabel("Occurrences")
    ax.set_ylabel("Probabilité estimée")
    ax.legend(loc="upper right")
    fig.savefig("Rapport/Figures/histogramme_Markov_Poisson_"+mot+".png")

# %% [markdown]
# #### Question 4
# Test de la fonction `proba_Poisson`.

# %%
probas_Poisson = projet.proba_Poisson(pb.encode_sequence("ATCTGC"), (a, c, g, t), M, 10000, eps = 1e-4)
for i, p in enumerate(probas_Poisson):
    print("P(N = {:d}) = {:.4f}".format(i, p))
# Out:
# P(N = 0) = 0.0869
# P(N = 1) = 0.2124
# P(N = 2) = 0.2593
# P(N = 3) = 0.2112
# P(N = 4) = 0.1289
# P(N = 5) = 0.0630
# P(N = 6) = 0.0256
# P(N = 7) = 0.0089
# P(N = 8) = 0.0027
# P(N = 9) = 0.0007
# P(N = 10) = 0.0002

# %% [markdown]
# Test de la fonction `proba_Poisson_ges_n`.

# %%
for i in range(12):
    print("P(N >= {:d}) = {:.4f}"
          .format(i, projet.proba_Poisson_geq_n(pb.encode_sequence("ATCTGC"), (a, c, g, t), M, 10000, i)))
# Out:
# P(N >= 0) = 1.0000
# P(N >= 1) = 0.9131
# P(N >= 2) = 0.7007
# P(N >= 3) = 0.4414
# P(N >= 4) = 0.2302
# P(N >= 5) = 0.1013
# P(N >= 6) = 0.0383
# P(N >= 7) = 0.0127
# P(N >= 8) = 0.0037
# P(N >= 9) = 0.0010
# P(N >= 10) = 0.0002
# P(N >= 11) = 0.0001

# %% [markdown]
# #### Question 5
# Test de la fonction `proba_Poisson_from_list` avec affichage de toutes les probabilités calculées.

# %%
mots = projet.proba_Poisson_from_list((a, c, g, t), M, 2, liste_PHO, 0.05, True)
# Out:
# Mot [0, 0] :
# 	Occurrences : 493
# 	P(N >= 493) = 0.0000
# Mot [0, 1] :
# 	Occurrences : 236
# 	P(N >= 236) = 0.1899
# Mot [0, 2] :
# 	Occurrences : 265
# 	P(N >= 265) = 0.0627
# Mot [0, 3] :
# 	Occurrences : 336
# 	P(N >= 336) = 0.7178
# Mot [1, 0] :
# 	Occurrences : 299
# 	P(N >= 299) = 0.0430
# Mot [1, 1] :
# 	Occurrences : 133
# 	P(N >= 133) = 0.9978
# Mot [1, 2] :
# 	Occurrences : 162
# 	P(N >= 162) = 0.0015
# Mot [1, 3] :
# 	Occurrences : 200
# 	P(N >= 200) = 0.9958
# Mot [2, 0] :
# 	Occurrences : 229
# 	P(N >= 229) = 0.9193
# Mot [2, 1] :
# 	Occurrences : 210
# 	P(N >= 210) = 0.0002
# Mot [2, 2] :
# 	Occurrences : 139
# 	P(N >= 139) = 0.9860
# Mot [2, 3] :
# 	Occurrences : 198
# 	P(N >= 198) = 0.9466
# Mot [3, 0] :
# 	Occurrences : 310
# 	P(N >= 310) = 0.1126
# Mot [3, 1] :
# 	Occurrences : 215
# 	P(N >= 215) = 0.9915
# Mot [3, 2] :
# 	Occurrences : 210
# 	P(N >= 210) = 0.9998
# Mot [3, 3] :
# 	Occurrences : 364
# 	P(N >= 364) = 0.9045
# [[0, 0], [1, 0], [1, 2], [2, 1]]

# %% [markdown]
# On calcule maintenant tous les mots `w` de longueurs 2, 4 ou 6 dans les séquences PHO, GAL et MET pour lesquels la probabilité que le nombre d'occurrences de `w` dans une séquence aléatoire obtenue par une chaîne de Markov soit supérieur ou égal au nombre d'occurrences observé dans la séquence est inférieure à `0.001`. Ces mots-là sont ceux qu'on identifie comme apparaissant significativement plus qu'attendu.

# %%
dict_lists = {"PHO": liste_PHO, "GAL": liste_GAL, "MET": liste_MET}
for seq in dict_lists:
    for k in [2, 4, 6, 8]:
        print("Séquence "+seq+", mots de longueur "+str(k)+" :")
        mots = projet.proba_Poisson_from_list((a, c, g, t), M, k, dict_lists[seq], 0.001)
        for mot in mots:
            print("".join([nucleotide_inverse[lettre] for lettre in mot]), end = " ")
        print()
    print()
# Out:
# Séquence PHO, mots de longueur 2 :
# AA GC
# Séquence PHO, mots de longueur 4 :
# AAAA AAGA ACGT AGAA CAGC CGTG TATA
# Séquence PHO, mots de longueur 6 :
# AAAAAA AAAAAG AAACGT AAATTA AAGAAA AAGAAG ACGTAT ACGTGC ACGTGG AGCAGC CAACAA CAAGAA CACGTG CGTGGG GAAGAA GCACGT GCAGCA GCAGCG TATATA TCATCT TGCCAA
# Séquence PHO, mots de longueur 8 :
# AAAAAAAA AAAAAAAG AAAAAAGA AAAGTAAA AACAACAA AAGAAATG AAGAAGAA ACACGTGG ACAGCAGC ACGCTCTC ACGTATAT ACGTGCAG AGAAGAAG AGCAGCGG AGGAAGAA ATAGGCGC ATATAAGC CAAAAAAA CAAGAATG CACACGTG CACGTGGG CAGCAGCG CCTCATCT CGGAAGAG CGTATATA CGTGCAGC CGTTTTCG CTCGTAAG GAAAAATT GAAGAAGA GCGTATTA GGAAGAGC GTATATAA TAAAAAAA TACGGGAC TATATAAG TCACACGT TCGTAAGG
#
# Séquence GAL, mots de longueur 2 :
#
# Séquence GAL, mots de longueur 4 :
# AAAA ATAT TATA TTTT
# Séquence GAL, mots de longueur 6 :
# AAAAAA TATATA TTTTTT
# Séquence GAL, mots de longueur 8 :
# AAAAAAAA AACACATA ACACATAG ATATACAT ATCATAAG ATCGGGGC CAACACAT CACCGGCG CAGTAATA CGGTCTTT CTCCGAAC CTTTTATG GCAACACA GCCGCACT GCGAAGCG GCGGTCTT GGCAGTAA GGCGGTCT GTAGAATC GTGGGGCC TACGGCAG TCCGTGCG TTAGATAT TTGAAAAT TTGCAAAC TTTTTTTT
#
# Séquence MET, mots de longueur 2 :
# AA
# Séquence MET, mots de longueur 4 :
# AAAA ATAA ATAT TATA TTTC TTTT
# Séquence MET, mots de longueur 6 :
# AAAAAA AAAAGG AAAATA AACTGT ACGTGA ATATAT ATTTCT CACGTG GAAAAA GTATAA GTGTGT TATAAG TATATA TCACGT TTTCTT TTTTTC TTTTTT
# Séquence MET, mots de longueur 8 :
# AAAAAAAA AAAAAAAG AAAAAAAT AAAAAAGG AAAACTGT AAACAAAA AAACTGTG AAAGGAGA AACTGTGG AAGAAAAA AAGCCACA ACGGCACC AGAAAAAA AGCCACAG AGGAAAGA AGGGCGTG AGTATAAT ATACACAT ATATAAGT ATATATAT ATATTTCT ATCATTTT ATTTCTTT CACGTGAC CACGTGAT CCCACGTG CCGGGTAA CGGCACCC CTATATAA CTCCCGGT CTGTGGCG GAAAAAAA GCGCATCC GGCGTGTG GGTAAAGG GGTACCGA GTGTGTTT TATATAAG TATATATA TATTTCTT TCAAAATA TCACGTGA TCATTTTC TCTTTTTT TGCACTAA TGTGGCGT TGTGTGTT TTCACGTG TTCACTCT TTCTTTTT TTTCACGT TTTCTTGC TTTCTTTT TTTTTTTT
